# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import os
import openweathermapy as ow
from urllib.error import HTTPError

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
#output_data_file = "output_data/cities.csv"
os.makedirs(os.path.join('output_data'),exist_ok=True)
output_data_file = os.path.join("output_data","cities.csv")

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 610

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
base_url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key 

setting = {'units':'Imperial','appid':weather_api_key}
retrieve_values = ['clouds.all','sys.country','dt','main.humidity','main.temp_max','wind.speed','coord.lat','coord.lon']

# %%
cloudiness = []
country = []
date = []
humidity = []
max_temp = []
wind_speed = []
lat =[]
lng =[]
cities_list = []

# %%
print('Starting Data Retrieval')
print('---------------------')
counter = 1
for city in cities:
    city_url = base_url + '&q=' + city.replace(' ','+')
    print(f'Processing City # {counter} | {city}')
    print(city_url)
    try:
        city_data = ow.get_current(city,**setting)
        cl,ct,dt,hm,mt,ws,lt,ln = city_data(*retrieve_values)
        cloudiness.append(cl)
        country.append(ct)
        date.append(dt)
        humidity.append(hm)
        max_temp.append(mt)
        wind_speed.append(ws)
        lat.append(lt)
        lng.append(ln)
        cities_list.append(city)
    except HTTPError:
        print('City not found. skipping...')
    counter += 1
print('---------------------')
print('Data Retrieval Complete')
# Out:
# Starting Data Retrieval
# ---------------------
# Processing City # 1 | hilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=hilo
# Processing City # 2 | busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=busselton
# Processing City # 3 | seoul
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=seoul
# Processing City # 4 | yar-sale
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=yar-sale
# Processing City # 5 | korla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=korla
# Processing City # 6 | castro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=castro
# Processing City # 7 | taolanaro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=taolanaro
# City not found. skipping...
# Processing City # 8 | iqaluit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=iqaluit
# Processing City # 9 | attawapiskat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=attawapiskat
# City not found. skipping...
# Processing City # 10 | richards bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=richards+bay
# Processing City # 11 | cidreira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=cidreira
# Processing City # 12 | saint-philippe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=saint-philippe
# Processing City # 13 | cape town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=cape+town
# Processing City # 14 | tsihombe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=tsihombe
# City not found. skipping...
# Processing City # 15 | khatanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=khatanga
# Processing City # 16 | bengkulu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=bengkulu
# Processing City # 17 | srednekolymsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=srednekolymsk
# Processing City # 18 | illoqqortoormiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=illoqqortoormiut
# City not found. skipping...
# Processing City # 19 | sentyabrskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=sentyabrskiy
# City not found. skipping...
# Processing City # 20 | kodiak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=kodiak
# Processing City # 21 | jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=jamestown
# Processing City # 22 | mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=mataura
# Processing City # 23 | rocha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=rocha
# Processing City # 24 | esperance
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=esperance
# Processing City # 25 | dingle
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=dingle
# Processing City # 26 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=yellowknife
# Processing City # 27 | rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=rikitea
# Processing City # 28 | totness
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=totness
# Processing City # 29 | vila franca do campo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=vila+franca+do+campo
# Processing City # 30 | poum
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=poum
# Processing City # 31 | bubaque
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=bubaque
# Processing City # 32 | kijang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=kijang
# Processing City # 33 | port alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=port+alfred
# Processing City # 34 | hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=hithadhoo
# Processing City # 35 | vanimo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=vanimo
# Processing City # 36 | jerez
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=jerez
# Processing City # 37 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=ushuaia
# Processing City # 38 | plainview
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=plainview
# Processing City # 39 | wahpeton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=wahpeton
# Processing City # 40 | pisco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=pisco
# Processing City # 41 | presidencia roque saenz pena
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=presidencia+roque+saenz+pena
# Processing City # 42 | luganville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=luganville
# Processing City # 43 | touros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=touros
# Processing City # 44 | mogadishu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=mogadishu
# Processing City # 45 | hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=hobart
# Processing City # 46 | port elizabeth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=port+elizabeth
# Processing City # 47 | qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=qaanaaq
# Processing City # 48 | butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=butaritari
# Processing City # 49 | boca do acre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=boca+do+acre
# Processing City # 50 | chokurdakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=chokurdakh
# Processing City # 51 | pacific grove
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=pacific+grove
# Processing City # 52 | cherepovets
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=cherepovets
# Processing City # 53 | ahuimanu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=ahuimanu
# Processing City # 54 | wukari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=wukari
# Processing City # 55 | hasaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=hasaki
# Processing City # 56 | longyearbyen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=longyearbyen
# Processing City # 57 | norman wells
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=norman+wells
# Processing City # 58 | kloulklubed
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=kloulklubed
# Processing City # 59 | saldanha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=saldanha
# Processing City # 60 | hami
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=hami
# Processing City # 61 | mstera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=mstera
# Processing City # 62 | arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=arraial+do+cabo
# Processing City # 63 | kaeo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=kaeo
# Processing City # 64 | kapit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=kapit
# Processing City # 65 | santarem
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=santarem
# Processing City # 66 | sorvag
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=sorvag
# City not found. skipping...
# Processing City # 67 | bluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=bluff
# Processing City # 68 | babanusah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=babanusah
# City not found. skipping...
# Processing City # 69 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=punta+arenas
# Processing City # 70 | bilibino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=bilibino
# Processing City # 71 | provideniya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=provideniya
# Processing City # 72 | marcona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=marcona
# City not found. skipping...
# Processing City # 73 | vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=vaini
# Processing City # 74 | opuwo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=opuwo
# Processing City # 75 | sorland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=sorland
# Processing City # 76 | olafsvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=olafsvik
# Processing City # 77 | tasiilaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=tasiilaq
# Processing City # 78 | koutiala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=koutiala
# Processing City # 79 | te anau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=te+anau
# Processing City # 80 | east london
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=east+london
# Processing City # 81 | caravelas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=caravelas
# Processing City # 82 | grand river south east
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=grand+river+south+east
# City not found. skipping...
# Processing City # 83 | albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=albany
# Processing City # 84 | char bhadrasan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=char+bhadrasan
# Processing City # 85 | weinan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=weinan
# Processing City # 86 | dobroye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=dobroye
# Processing City # 87 | northam
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=northam
# Processing City # 88 | muzquiz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=muzquiz
# City not found. skipping...
# Processing City # 89 | fortuna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=fortuna
# Processing City # 90 | marathon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=marathon
# Processing City # 91 | wakkanai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=wakkanai
# Processing City # 92 | apricena
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=apricena
# Processing City # 93 | fomboni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=fomboni
# Processing City # 94 | ponta do sol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=ponta+do+sol
# Processing City # 95 | banamba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=banamba
# Processing City # 96 | khonuu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=khonuu
# City not found. skipping...
# Processing City # 97 | coihaique
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=coihaique
# Processing City # 98 | swan river
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=swan+river
# Processing City # 99 | dibaya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=dibaya
# City not found. skipping...
# Processing City # 100 | usinsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=usinsk
# Processing City # 101 | codrington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=codrington
# Processing City # 102 | puerto ayora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=puerto+ayora
# Processing City # 103 | mys shmidta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=mys+shmidta
# City not found. skipping...
# Processing City # 104 | hay river
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=hay+river
# Processing City # 105 | rio grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=rio+grande
# Processing City # 106 | flin flon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=flin+flon
# Processing City # 107 | najran
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=najran
# Processing City # 108 | kazalinsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=kazalinsk
# City not found. skipping...
# Processing City # 109 | basavana bagevadi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=basavana+bagevadi
# Processing City # 110 | tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=tuktoyaktuk
# Processing City # 111 | sept-iles
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=sept-iles
# Processing City # 112 | banjar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=banjar
# Processing City # 113 | galiwinku
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=galiwinku
# City not found. skipping...
# Processing City # 114 | bambous virieux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=bambous+virieux
# Processing City # 115 | xining
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=xining
# Processing City # 116 | grimari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=grimari
# City not found. skipping...
# Processing City # 117 | sao joao da barra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=sao+joao+da+barra
# Processing City # 118 | nikolskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=nikolskoye
# Processing City # 119 | atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=atuona
# Processing City # 120 | saleaula
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=saleaula
# City not found. skipping...
# Processing City # 121 | tura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=tura
# Processing City # 122 | vossevangen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=vossevangen
# Processing City # 123 | warkworth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=warkworth
# Processing City # 124 | bethel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=bethel
# Processing City # 125 | lorengau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=lorengau
# Processing City # 126 | talnakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=talnakh
# Processing City # 127 | tuatapere
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=tuatapere
# Processing City # 128 | brainerd
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=brainerd
# Processing City # 129 | belmonte
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=belmonte
# Processing City # 130 | petropavlovsk-kamchatskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=petropavlovsk-kamchatskiy
# Processing City # 131 | sinnamary
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=sinnamary
# Processing City # 132 | hambantota
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=hambantota
# Processing City # 133 | labutta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=labutta
# City not found. skipping...
# Processing City # 134 | severo-kurilsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=severo-kurilsk
# Processing City # 135 | anadyr
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=anadyr
# Processing City # 136 | atikokan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=atikokan
# Processing City # 137 | saryg-sep
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=saryg-sep
# Processing City # 138 | belushya guba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=belushya+guba
# City not found. skipping...
# Processing City # 139 | bonavista
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=bonavista
# Processing City # 140 | ancud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=ancud
# Processing City # 141 | zhanaozen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=zhanaozen
# Processing City # 142 | kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=kapaa
# Processing City # 143 | hamilton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=hamilton
# Processing City # 144 | luena
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=luena
# Processing City # 145 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=bredasdorp
# Processing City # 146 | tikaitnagar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=tikaitnagar
# Processing City # 147 | zolotinka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=zolotinka
# City not found. skipping...
# Processing City # 148 | hofn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=hofn
# Processing City # 149 | yorosso
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=yorosso
# Processing City # 150 | saint-francois
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=saint-francois
# Processing City # 151 | boljarovo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=boljarovo
# City not found. skipping...
# Processing City # 152 | berlevag
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=berlevag
# Processing City # 153 | mackenzie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=mackenzie
# Processing City # 154 | alenquer
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=alenquer
# Processing City # 155 | north bend
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=north+bend
# Processing City # 156 | new norfolk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=new+norfolk
# Processing City # 157 | santa rosa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=santa+rosa
# Processing City # 158 | bathsheba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=bathsheba
# Processing City # 159 | kuli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=kuli
# Processing City # 160 | atlantic city
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=atlantic+city
# Processing City # 161 | san jeronimo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=san+jeronimo
# Processing City # 162 | chuy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=chuy
# Processing City # 163 | victoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=victoria
# Processing City # 164 | labuhan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=labuhan
# Processing City # 165 | gizo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=gizo
# Processing City # 166 | mitu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=mitu
# Processing City # 167 | mar del plata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=mar+del+plata
# Processing City # 168 | avarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=avarua
# Processing City # 169 | kaabong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=kaabong
# Processing City # 170 | gat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=gat
# Processing City # 171 | bereda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=bereda
# Processing City # 172 | barrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=barrow
# Processing City # 173 | westlock
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=westlock
# Processing City # 174 | sirjan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=sirjan
# Processing City # 175 | saint george
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=saint+george
# Processing City # 176 | bandrele
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=bandrele
# Processing City # 177 | poronaysk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=poronaysk
# Processing City # 178 | torbay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=torbay
# Processing City # 179 | puerto leguizamo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=puerto+leguizamo
# Processing City # 180 | chadan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=chadan
# Processing City # 181 | hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=hermanus
# Processing City # 182 | chimbote
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=chimbote
# Processing City # 183 | palasbari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=palasbari
# Processing City # 184 | belyy yar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=belyy+yar
# Processing City # 185 | alyangula
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=alyangula
# Processing City # 186 | vaitupu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=vaitupu
# City not found. skipping...
# Processing City # 187 | luderitz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=luderitz
# Processing City # 188 | ribeira grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=ribeira+grande
# Processing City # 189 | codajas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=codajas
# Processing City # 190 | darhan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=darhan
# Processing City # 191 | columbus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=columbus
# Processing City # 192 | san cristobal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=san+cristobal
# Processing City # 193 | karanja
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=karanja
# Processing City # 194 | manturovo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=manturovo
# Processing City # 195 | sao filipe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=sao+filipe
# Processing City # 196 | esmeraldas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=esmeraldas
# Processing City # 197 | baykit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=baykit
# Processing City # 198 | aykhal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=aykhal
# Processing City # 199 | klyuchi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=klyuchi
# Processing City # 200 | quang ngai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=quang+ngai
# Processing City # 201 | wuwei
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=wuwei
# Processing City # 202 | maragogi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=maragogi
# Processing City # 203 | ola
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=ola
# Processing City # 204 | laguna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=laguna
# Processing City # 205 | upernavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=upernavik
# Processing City # 206 | kavieng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=kavieng
# Processing City # 207 | klaksvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=klaksvik
# Processing City # 208 | axim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=axim
# Processing City # 209 | nazca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=nazca
# Processing City # 210 | acapulco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=acapulco
# Processing City # 211 | amderma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=amderma
# City not found. skipping...
# Processing City # 212 | ati
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=ati
# Processing City # 213 | pingliang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=pingliang
# Processing City # 214 | dikson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=dikson
# Processing City # 215 | georgetown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=georgetown
# Processing City # 216 | cabo san lucas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=cabo+san+lucas
# Processing City # 217 | ajdabiya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=ajdabiya
# Processing City # 218 | saskylakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=saskylakh
# Processing City # 219 | warrington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=warrington
# Processing City # 220 | avera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=avera
# Processing City # 221 | vao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=vao
# Processing City # 222 | dalbandin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=dalbandin
# Processing City # 223 | san ignacio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=san+ignacio
# Processing City # 224 | mahebourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=mahebourg
# Processing City # 225 | barentsburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=barentsburg
# City not found. skipping...
# Processing City # 226 | constitucion
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=constitucion
# Processing City # 227 | udachnyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=udachnyy
# Processing City # 228 | bayir
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=bayir
# Processing City # 229 | victor harbor
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=victor+harbor
# Processing City # 230 | lebu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=lebu
# Processing City # 231 | hirado
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=hirado
# Processing City # 232 | pemberton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=pemberton
# Processing City # 233 | rzhanitsa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=rzhanitsa
# Processing City # 234 | maldonado
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=maldonado
# Processing City # 235 | along
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=along
# Processing City # 236 | palabuhanratu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=palabuhanratu
# City not found. skipping...
# Processing City # 237 | cuiluan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=cuiluan
# Processing City # 238 | novo aripuana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=novo+aripuana
# Processing City # 239 | thompson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=thompson
# Processing City # 240 | grand centre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=grand+centre
# City not found. skipping...
# Processing City # 241 | kathu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=kathu
# Processing City # 242 | shimoda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=shimoda
# Processing City # 243 | kachiry
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=kachiry
# Processing City # 244 | aklavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=aklavik
# Processing City # 245 | mucurapo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=mucurapo
# Processing City # 246 | tiksi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=tiksi
# Processing City # 247 | isangel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=isangel
# Processing City # 248 | pacifica
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=pacifica
# Processing City # 249 | finschhafen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=finschhafen
# Processing City # 250 | houston
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=houston
# Processing City # 251 | damietta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=damietta
# Processing City # 252 | mioveni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=mioveni
# Processing City # 253 | saint-pierre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=saint-pierre
# Processing City # 254 | nanortalik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=nanortalik
# Processing City # 255 | bandundu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=bandundu
# Processing City # 256 | pushkino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=pushkino
# Processing City # 257 | san patricio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=san+patricio
# Processing City # 258 | nhulunbuy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=nhulunbuy
# Processing City # 259 | sorso
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=sorso
# Processing City # 260 | priargunsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=priargunsk
# Processing City # 261 | bageshwar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=bageshwar
# Processing City # 262 | hobyo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=hobyo
# Processing City # 263 | salalah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=salalah
# Processing City # 264 | leningradskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=leningradskiy
# Processing City # 265 | guerrero negro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=guerrero+negro
# Processing City # 266 | kampot
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=kampot
# Processing City # 267 | harper
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=harper
# Processing City # 268 | mansa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=mansa
# Processing City # 269 | souillac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=souillac
# Processing City # 270 | burdur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=burdur
# Processing City # 271 | mana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=mana
# Processing City # 272 | nizhneyansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=nizhneyansk
# City not found. skipping...
# Processing City # 273 | airai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=airai
# Processing City # 274 | ambon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=ambon
# Processing City # 275 | ixtapa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=ixtapa
# Processing City # 276 | lac du bonnet
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=lac+du+bonnet
# Processing City # 277 | dongkan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=dongkan
# Processing City # 278 | zlatoustovsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=zlatoustovsk
# City not found. skipping...
# Processing City # 279 | malabuyoc
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=malabuyoc
# Processing City # 280 | tongzhou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=tongzhou
# Processing City # 281 | heihe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=heihe
# Processing City # 282 | lavrentiya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=lavrentiya
# Processing City # 283 | naze
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=naze
# Processing City # 284 | amreli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=amreli
# Processing City # 285 | benguela
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=benguela
# Processing City # 286 | cap malheureux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=cap+malheureux
# Processing City # 287 | great yarmouth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=great+yarmouth
# Processing City # 288 | peace river
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=peace+river
# Processing City # 289 | karkaralinsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=karkaralinsk
# City not found. skipping...
# Processing City # 290 | orlik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=orlik
# Processing City # 291 | porto novo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=porto+novo
# Processing City # 292 | nelson bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=nelson+bay
# Processing City # 293 | ostrovnoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=ostrovnoy
# Processing City # 294 | buraydah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=buraydah
# Processing City # 295 | brake
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=brake
# Processing City # 296 | los cedrales
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=los+cedrales
# Processing City # 297 | kudahuvadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=kudahuvadhoo
# Processing City # 298 | talaya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=talaya
# Processing City # 299 | gangapur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=gangapur
# Processing City # 300 | kuryk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=kuryk
# Processing City # 301 | sibolga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=sibolga
# Processing City # 302 | shizuishan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=shizuishan
# Processing City # 303 | zanjan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=zanjan
# Processing City # 304 | toluviejo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=toluviejo
# Processing City # 305 | vikindu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=vikindu
# Processing City # 306 | kibaha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=kibaha
# Processing City # 307 | haines junction
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=haines+junction
# Processing City # 308 | wajima
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=wajima
# Processing City # 309 | tiznit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=tiznit
# Processing City # 310 | banda aceh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=banda+aceh
# Processing City # 311 | alta floresta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=alta+floresta
# Processing City # 312 | dromolaxia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=dromolaxia
# Processing City # 313 | atar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=atar
# Processing City # 314 | spring hill
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=spring+hill
# Processing City # 315 | englehart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=englehart
# Processing City # 316 | alpena
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=alpena
# Processing City # 317 | inhambane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=inhambane
# Processing City # 318 | hihifo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=hihifo
# City not found. skipping...
# Processing City # 319 | port hedland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=port+hedland
# Processing City # 320 | kazanskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=kazanskoye
# Processing City # 321 | talakan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=talakan
# Processing City # 322 | bergerac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=bergerac
# Processing City # 323 | tres picos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=tres+picos
# Processing City # 324 | dicabisagan
# ...
# Processing City # 505 | srandakan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=srandakan
# Processing City # 506 | asosa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=asosa
# Processing City # 507 | tumannyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=tumannyy
# City not found. skipping...
# Processing City # 508 | itapetininga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=itapetininga
# Processing City # 509 | cairns
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=cairns
# Processing City # 510 | lompoc
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=lompoc
# Processing City # 511 | livingstone
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=livingstone
# Processing City # 512 | maumere
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=maumere
# Processing City # 513 | nioro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=nioro
# Processing City # 514 | alofi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=alofi
# Processing City # 515 | gazanjyk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=gazanjyk
# Processing City # 516 | bensonville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=bensonville
# Processing City # 517 | manbij
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=manbij
# Processing City # 518 | pangnirtung
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=pangnirtung
# Processing City # 519 | dubrovnik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=dubrovnik
# Processing City # 520 | mayo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=mayo
# Processing City # 521 | loikaw
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=loikaw
# Processing City # 522 | emba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=emba
# Processing City # 523 | mahajanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=mahajanga
# Processing City # 524 | shenjiamen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=shenjiamen
# Processing City # 525 | choix
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=choix
# Processing City # 526 | college
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=college
# Processing City # 527 | peniche
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=peniche
# Processing City # 528 | los llanos de aridane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=los+llanos+de+aridane
# Processing City # 529 | bardiyah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=bardiyah
# Processing City # 530 | nabire
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=nabire
# Processing City # 531 | kinshasa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=kinshasa
# Processing City # 532 | iranshahr
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=iranshahr
# Processing City # 533 | ichinoseki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=ichinoseki
# Processing City # 534 | martil
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=martil
# Processing City # 535 | deputatskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=deputatskiy
# Processing City # 536 | bolungarvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=bolungarvik
# City not found. skipping...
# Processing City # 537 | chapais
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=chapais
# Processing City # 538 | rawson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=rawson
# Processing City # 539 | nuuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=nuuk
# Processing City # 540 | grand gaube
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=grand+gaube
# Processing City # 541 | krasnoselkup
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=krasnoselkup
# Processing City # 542 | gondar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=gondar
# Processing City # 543 | calarasi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=calarasi
# Processing City # 544 | falealupo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=falealupo
# City not found. skipping...
# Processing City # 545 | roswell
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=roswell
# Processing City # 546 | umm durman
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=umm+durman
# City not found. skipping...
# Processing City # 547 | half moon bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=half+moon+bay
# Processing City # 548 | la jagua del pilar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=la+jagua+del+pilar
# Processing City # 549 | fairview
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=fairview
# Processing City # 550 | bad neuenahr-ahrweiler
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=bad+neuenahr-ahrweiler
# Processing City # 551 | gorgan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=gorgan
# Processing City # 552 | one hundred mile house
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=one+hundred+mile+house
# City not found. skipping...
# Processing City # 553 | marshalltown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=marshalltown
# Processing City # 554 | carpina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=carpina
# Processing City # 555 | oranjemund
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=oranjemund
# Processing City # 556 | harsin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=harsin
# Processing City # 557 | halifax
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=halifax
# Processing City # 558 | puerto colombia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=puerto+colombia
# Processing City # 559 | noormarkku
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=noormarkku
# Processing City # 560 | faanui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=faanui
# Processing City # 561 | sioux lookout
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=sioux+lookout
# Processing City # 562 | biak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=biak
# Processing City # 563 | maniitsoq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=maniitsoq
# Processing City # 564 | ugoofaaru
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=ugoofaaru
# Processing City # 565 | pueblo nuevo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=pueblo+nuevo
# Processing City # 566 | lima
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=lima
# Processing City # 567 | aquiles serdan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=aquiles+serdan
# Processing City # 568 | tessalit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=tessalit
# Processing City # 569 | sandy bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=sandy+bay
# Processing City # 570 | pimenta bueno
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=pimenta+bueno
# Processing City # 571 | sao jose da coroa grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=sao+jose+da+coroa+grande
# Processing City # 572 | goderich
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=goderich
# Processing City # 573 | gubskaya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=gubskaya
# Processing City # 574 | alice springs
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=alice+springs
# Processing City # 575 | cedar city
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=cedar+city
# Processing City # 576 | bhakkar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=bhakkar
# Processing City # 577 | presidente medici
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=presidente+medici
# Processing City # 578 | constantine
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=constantine
# Processing City # 579 | lundazi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=lundazi
# Processing City # 580 | skjervoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=skjervoy
# Processing City # 581 | zachagansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=zachagansk
# City not found. skipping...
# Processing City # 582 | tateyama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=tateyama
# Processing City # 583 | mocambique
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=mocambique
# City not found. skipping...
# Processing City # 584 | fairbanks
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=fairbanks
# Processing City # 585 | kieta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=kieta
# Processing City # 586 | baruun-urt
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=baruun-urt
# Processing City # 587 | nizhnyaya omka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=nizhnyaya+omka
# Processing City # 588 | piraju
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=piraju
# Processing City # 589 | pondicherry
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=pondicherry
# Processing City # 590 | methoni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=methoni
# Processing City # 591 | ossora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=ossora
# Processing City # 592 | golyshmanovo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=golyshmanovo
# Processing City # 593 | la reforma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=la+reforma
# Processing City # 594 | binzhou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=binzhou
# Processing City # 595 | calabozo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=calabozo
# Processing City # 596 | okha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=okha
# Processing City # 597 | pueblo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=pueblo
# Processing City # 598 | nguiu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=nguiu
# City not found. skipping...
# Processing City # 599 | lakhdenpokhya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=lakhdenpokhya
# Processing City # 600 | broome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=broome
# Processing City # 601 | maltahohe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=maltahohe
# Processing City # 602 | umzimvubu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=umzimvubu
# City not found. skipping...
# Processing City # 603 | giarmata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=giarmata
# Processing City # 604 | palu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=palu
# Processing City # 605 | tabou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=tabou
# Processing City # 606 | boralday
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=boralday
# Processing City # 607 | geraldton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=geraldton
# Processing City # 608 | charters towers
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=charters+towers
# Processing City # 609 | saint anthony
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=saint+anthony
# Processing City # 610 | prachuap khiri khan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3d713bff12eb539c8d4f2ab2e6905d9d&q=prachuap+khiri+khan
# ---------------------
# Data Retrieval Complete

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather = pd.DataFrame({
     'City':cities_list,
     'Cloudiness':cloudiness,
     'Country':country,
     'Date':date,
     'Humidity':humidity,
     'Lat':lat,
     'Lng':lng,
     'Max Temperature':max_temp,
     'Wind Speed':wind_speed,
     })

# Ouput to csv
weather.to_csv(output_data_file)

# %%
weather.head()
# Out:
#         City  Cloudiness Country        Date  Humidity      Lat       Lng  \
# 0       hilo          90      US  1612411136        57  19.7297 -155.0900
# 1  busselton           0      AU  1612411136        42 -33.6500  115.3333
# 2      seoul           0      KR  1612411136        26  37.5683  126.9778
# 3   yar-sale          98      RU  1612411136        91  66.8333   70.8333
# 4      korla           0      CN  1612411136        75  41.7597   86.1469
#
#    Max Temperature  Wind Speed
# 0            78.80        9.22
# 1            73.00        3.00
# 2            28.40        2.30
# 3            -6.72       10.63
# 4            33.26        3.58

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
humid_places = weather.loc[(weather['Humidity']>100)]
humid_places
# Out:
# Empty DataFrame
# Columns: [City, Cloudiness, Country, Date, Humidity, Lat, Lng, Max Temperature, Wind Speed]
# Index: []

# %%
#  Get the indices of cities that have humidity over 100%.
#non

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
def plot_lat(y,y_label):
    lat_y = plt.scatter(weather['Lat'],weather[y],alpha=0.75,edgecolors='red')
    plt.title(f"City Latitude vs. {y} ({time.strftime('%m/%d/%y')})")
    plt.xlabel('Latitude') 
    plt.ylabel(y_label)
    plt.xlim(-80,100)
    plt.ylim(min(weather[y])-20,max(weather[y])+20)
    plt.grid()
    plt.savefig(os.path.join('output_data',f'Latitude_vs_{y}.png'))

# %%
lat_temp = plot_lat(y='Max Temperature',y_label='Max Temperature (F)')
lat_temp

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
lat_humidity = plot_lat(y='Humidity',y_label='Humidity (%)')
lat_humidity

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
lat_cloud = plot_lat(y='Cloudiness',y_label='Cloudiness (%)')
lat_cloud

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
lat_wind = plot_lat(y='Wind Speed',y_label='Wind Speed (mph)')
lat_wind

# %% [markdown]
# ## Linear Regression

# %%
northern_hem = weather.loc[(weather['Lat']>0)]
northern_hem
# Out:
#                     City  Cloudiness Country        Date  Humidity      Lat  \
# 0                   hilo          90      US  1612411136        57  19.7297
# 2                  seoul           0      KR  1612411136        26  37.5683
# 3               yar-sale          98      RU  1612411136        91  66.8333
# 4                  korla           0      CN  1612411136        75  41.7597
# 6                iqaluit          90      CA  1612411028        77  63.7506
# ..                   ...         ...     ...         ...       ...      ...
# 544             giarmata          40      RO  1612411232       100  45.8383
# 546                tabou          10      CI  1612411233        90   4.4230
# 547             boralday          90      KZ  1612411233        93  43.3578
# 550        saint anthony          90      US  1612411026        80  45.0205
# 551  prachuap khiri khan          17      TH  1612411234        65  12.2167
#
#           Lng  Max Temperature  Wind Speed
# 0   -155.0900            78.80        9.22
# 2    126.9778            28.40        2.30
# 3     70.8333            -6.72       10.63
# 4     86.1469            33.26        3.58
# 6    -68.5145            -4.00        2.30
# ..        ...              ...         ...
# 544   21.3108            48.99        9.22
# 546   -7.3528            77.90        6.73
# 547   76.8594            24.80        4.47
# 550  -93.2180            30.99       10.36
# 551   99.7500            84.20        3.44
#
# [394 rows x 9 columns]

# %%
southern_hem = weather.loc[(weather['Lat']<0)]
southern_hem
# Out:
#                 City  Cloudiness Country        Date  Humidity      Lat  \
# 1          busselton           0      AU  1612411136        42 -33.6500
# 5             castro         100      BR  1612411087        91 -24.7911
# 7       richards bay         100      ZA  1612411007        90 -28.7830
# 8           cidreira         100      BR  1612411137        92 -30.1811
# 9     saint-philippe           0      RE  1612411137        61 -21.3585
# ..               ...         ...     ...         ...       ...      ...
# 531           piraju         100      BR  1612411228        84 -23.1936
# 543        maltahohe          10      NA  1612411232        33 -24.8333
# 545             palu         100      ID  1612411233        58  -0.8917
# 548        geraldton          40      AU  1612411233        39 -28.7667
# 549  charters towers          64      AU  1612411042        50 -20.1000
#
#           Lng  Max Temperature  Wind Speed
# 1    115.3333            73.00        3.00
# 5    -50.0119            68.31        2.46
# 7     32.0377            74.08        5.12
# 8    -50.2056            76.08        7.49
# 9     55.7679            82.99        4.61
# ..        ...              ...         ...
# 531  -49.3839            73.35        1.57
# 543   16.9833            71.42       10.42
# 545  119.8707            87.15        4.45
# 548  114.6000            82.40       26.46
# 549  146.2667            88.50       10.36
#
# [158 rows x 9 columns]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
def plotLinearRegression(xdata,ydata,xlbl,ylbl,lblpos,ifig):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(xdata, ydata)
    print(f"The r-squared is: {rvalue}")
    regress_values = xdata * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

    plt.scatter(xdata,ydata)
    plt.plot(xdata,regress_values,"r-")
    plt.annotate(line_eq,lblpos,fontsize=15,color="red")
    plt.xlabel(xlbl)
    plt.ylabel(ylbl)
    plt.savefig(f"output_data/fig{ifig}.png")
    plt.show()

# %%
xlbl = "Lat"
ylbl = "Max Temperature"
lblpos = (0,-5)
plotLinearRegression(northern_hem[xlbl],northern_hem[ylbl],xlbl,ylbl,lblpos,5)
# Out:
# The r-squared is: -0.8899711249233715

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
xlbl = "Lat"
ylbl = "Max Temperature"
lblpos = (-30,55)
plotLinearRegression(southern_hem[xlbl],southern_hem[ylbl],xlbl,ylbl,lblpos,5)
# Out:
# The r-squared is: 0.43530355578864044

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
xlbl = "Lat"
ylbl = "Humidity"
lblpos = (42,20)
plotLinearRegression(northern_hem[xlbl],northern_hem[ylbl],xlbl,ylbl,lblpos,5)
# Out:
# The r-squared is: 0.35407528843522423

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
xlbl = "Lat"
ylbl = "Humidity"
lblpos = (-25,25)
plotLinearRegression(southern_hem[xlbl],southern_hem[ylbl],xlbl,ylbl,lblpos,5)
# Out:
# The r-squared is: 0.2991620034284375

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
xlbl = "Lat"
ylbl = "Cloudiness"
lblpos = (42,15)
plotLinearRegression(northern_hem[xlbl],northern_hem[ylbl],xlbl,ylbl,lblpos,5)
# Out:
# The r-squared is: 0.28064825385422876

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
xlbl = "Lat"
ylbl = "Cloudiness"
lblpos = (-50,20)
plotLinearRegression(southern_hem[xlbl],southern_hem[ylbl],xlbl,ylbl,lblpos,5)
# Out:
# The r-squared is: 0.27067288870877076

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
xlbl = "Lat"
ylbl = "Wind Speed"
lblpos = (42,45)
plotLinearRegression(northern_hem[xlbl],northern_hem[ylbl],xlbl,ylbl,lblpos,5)
# Out:
# The r-squared is: 0.018797274642270306

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
xlbl = "Lat"
ylbl = "Wind Speed"
lblpos = (-30,23)
plotLinearRegression(southern_hem[xlbl],southern_hem[ylbl],xlbl,ylbl,lblpos,4)
# Out:
# The r-squared is: -0.2849756147348305
